# %% [markdown]
# # The Snitch — Colab Demo
#
# Three cells: install, generate traces + run baseline, train overseer + plot.

# %%
# Cell 1 — install
# !git clone https://github.com/infranova/snitch-env.git || true
# %cd snitch-env
# !pip install -q -e .

# %%
# Cell 2 — generate traces from checked-in questions.json and run random baseline
# !python scripts/generate_traces.py
# !python scripts/eval_baseline.py --n 200

# %%
# Cell 3 — train GRPO overseer, evaluate, and plot the hero chart
# !python training/train_grpo.py --model Qwen/Qwen2.5-0.5B-Instruct --n-train 400 --epochs 1
# !python training/eval.py --model checkpoints/snitch-grpo
# !python training/plot_results.py
from IPython.display import Image
Image('results/hero.png')
